# %% [markdown]
# # NMF Movie Recommender

# %%
import pandas as pd
import numpy as np
import math
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from sqlalchemy import Table, Column, String, Integer, Float
import surprise
from surprise import Dataset
from surprise import Reader

# %% [markdown]
# ## 1. Import the data from movielens (small 100k dataset)

# %% [markdown]
# ### Ratings Data
# Ratings are made on a 5-star scale, with half-star increments (0.5 stars - 5.0 stars).
# Timestamps represent seconds since midnight Coordinated Universal Time (UTC) of January 1, 1970.

# %%
ratings = pd.read_csv("ml-latest-small/ratings.csv")

# %% [markdown]
# ### Tags Data

# %%
tags = pd.read_csv("ml-latest-small/tags.csv")

# %% [markdown]
# ### Movie Data

# %%
movies = pd.read_csv("ml-latest-small/movies.csv")

# %% [markdown]
# ### Links Data
# Identifiers that can be used to link to other sources of movie data are contained in the file `links.csv`. Each line of this file after the header row represents one movie, and has the following format:
#
#     movieId,imdbId,tmdbId
#
# movieId is an identifier for movies used by <https://movielens.org>. E.g., the movie Toy Story has the link <https://movielens.org/movies/1>.
#
# imdbId is an identifier for movies used by <http://www.imdb.com>. E.g., the movie Toy Story has the link <http://www.imdb.com/title/tt0114709/>.
#
# tmdbId is an identifier for movies used by <https://www.themoviedb.org>. E.g., the movie Toy Story has the link <https://www.themoviedb.org/movie/862>.

# %%
links = pd.read_csv("ml-latest-small/links.csv")

# %% [markdown]
# ## 2. Read data into psql tables

# %% [markdown]
# ### 2.1 Create a database connection

# %%
s= 'postgres://localhost/movielens'
engine = create_engine(s, echo=True)

# %%
ratings.to_sql('ratings',engine, if_exists='replace')
# Out:
# 2019-08-03 13:58:35,492 INFO sqlalchemy.engine.base.Engine select version()
# 2019-08-03 13:58:35,493 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:58:35,499 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2019-08-03 13:58:35,499 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:58:35,506 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-08-03 13:58:35,506 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:58:35,512 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-08-03 13:58:35,513 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:58:35,514 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2019-08-03 13:58:35,515 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:58:35,520 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-08-03 13:58:35,521 INFO sqlalchemy.engine.base.Engine {'name': 'ratings'}
# 2019-08-03 13:58:35,528 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-08-03 13:58:35,530 INFO sqlalchemy.engine.base.Engine {'name': 'ratings'}
# 2019-08-03 13:58:35,542 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2019-08-03 13:58:35,544 INFO sqlalchemy.engine.base.Engine {'schema': 'public'}
# 2019-08-03 13:58:35,554 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2019-08-03 13:58:35,555 INFO sqlalchemy.engine.base.Engine {'table_name': 'ratings'}
# 2019-08-03 13:58:35,565 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2019-08-03 13:58:35,566 INFO sqlalchemy.engine.base.Engine {'table_oid': 24725}
# 2019-08-03 13:58:35,581 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2019-08-03 13:58:35,586 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:58:35,604 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2019-08-03 13:58:35,607 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:58:35,618 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2019-08-03 13:58:35,618 INFO sqlalchemy.engine.base.Engine {'table_oid': 24725}
# 2019-08-03 13:58:35,700 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2019-08-03 13:58:35,701 INFO sqlalchemy.engine.base.Engine {'table_oid': 24725}
# 2019-08-03 13:58:35,708 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2019-08-03 13:58:35,712 INFO sqlalchemy.engine.base.Engine {'table': 24725}
# 2019-08-03 13:58:35,729 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2019-08-03 13:58:35,732 INFO sqlalchemy.engine.base.Engine {'table_oid': 24725}
# 2019-08-03 13:58:35,740 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2019-08-03 13:58:35,742 INFO sqlalchemy.engine.base.Engine {'table_oid': 24725}
# 2019-08-03 13:58:35,746 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2019-08-03 13:58:35,747 INFO sqlalchemy.engine.base.Engine {'table_oid': 24725}
# 2019-08-03 13:58:35,752 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
# 2019-08-03 13:58:35,753 INFO sqlalchemy.engine.base.Engine {'table_oid': 24725}
# 2019-08-03 13:58:35,759 INFO sqlalchemy.engine.base.Engine
# DROP TABLE ratings
# 2019-08-03 13:58:35,760 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:58:35,798 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-08-03 13:58:35,825 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE ratings (
# 	index BIGINT,
# 	"userId" BIGINT,
# 	"movieId" BIGINT,
# 	rating FLOAT(53),
# 	timestamp BIGINT
# )
#
#
# 2019-08-03 13:58:35,828 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:58:35,901 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-08-03 13:58:35,910 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_ratings_index ON ratings (index)
# 2019-08-03 13:58:35,911 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:58:35,932 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-08-03 13:58:35,999 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-08-03 13:58:36,794 INFO sqlalchemy.engine.base.Engine INSERT INTO ratings (index, "userId", "movieId", rating, timestamp) VALUES (%(index)s, %(userId)s, %(movieId)s, %(rating)s, %(timestamp)s)
# 2019-08-03 13:58:36,795 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'userId': 1, 'movieId': 1, 'rating': 4.0, 'timestamp': 964982703}, {'index': 1, 'userId': 1, 'movieId': 3, 'rating': 4.0, 'timestamp': 964981247}, {'index': 2, 'userId': 1, 'movieId': 6, 'rating': 4.0, 'timestamp': 964982224}, {'index': 3, 'userId': 1, 'movieId': 47, 'rating': 5.0, 'timestamp': 964983815}, {'index': 4, 'userId': 1, 'movieId': 50, 'rating': 5.0, 'timestamp': 964982931}, {'index': 5, 'userId': 1, 'movieId': 70, 'rating': 3.0, 'timestamp': 964982400}, {'index': 6, 'userId': 1, 'movieId': 101, 'rating': 5.0, 'timestamp': 964980868}, {'index': 7, 'userId': 1, 'movieId': 110, 'rating': 4.0, 'timestamp': 964982176}  ... displaying 10 of 100836 total bound parameter sets ...  {'index': 100834, 'userId': 610, 'movieId': 168252, 'rating': 5.0, 'timestamp': 1493846352}, {'index': 100835, 'userId': 610, 'movieId': 170875, 'rating': 3.0, 'timestamp': 1493846415})
# 2019-08-03 13:58:57,669 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
movies.to_sql('movies', engine, if_exists='replace')

# %%
links.to_sql("links", engine, if_exists='replace')

# %%
tags.to_sql('tags', engine, if_exists='replace')

# %% [markdown]
# ### 2.2 Create a pivot table containing the movie ratings grouped by user
# * sql - filter and groupby
# * Psql - crosstab
# * pandas - pivot_table()

# %%
user_movie_ratings = pd.pivot_table(ratings, values="rating", index="userId", columns="movieId")

# %%
matrix_median = np.median(user_movie_ratings.median().values)
user_movie_ratings.fillna(matrix_median, inplace= True)
user_movie_ratings = user_movie_ratings.T

# %%
user_movie_ratings.to_sql("user_movie_ratings", engine)

# %% [markdown]
# ### 2.2 Create a declarative base (which allows to access all aspects of the Object Relational Mapper)

# %%
base = declarative_base(engine)
Session = sessionmaker(engine)
session = Session()

# %% [markdown]
# **Option: Setup tables using python class structure:**
# * We have to initialise the classes, which will by default create tables in our database.
# * But it doesn't get around having to input the data - I haven't tried a direct sqlalchemy route, but https://stackoverflow.com/questions/31394998/using-sqlalchemy-to-load-csv-file-into-a-database might work
# * Its possible ext.automap_base() gets around this requirement but I haven't tested it

# %%
#class Ratings:
    
#    __tablename__ = 'ratings'
#    userid = Column(Integer)
#    movieid = Column(Integer)
#    rating = Column(Float)
#    timestamp = Column(Integer)
    
#    def __repr__():
#        return f'{userid}_{movieid}_{rating}'

# %%
#class Movies:
    
#    __tablename__ = 'movies'
#    movieid = Column(Integer)
#    title = Column(String)
#    genre = Column(String)
    
#    def __repr__():
#        return f'{movieid}_{title}_{genre}'

# %%
#class Tags:
    
#    __tablename__ = 'tags'
#    userid = Column(Integer)
#    movieid = Column(Integer)
#    tag = Column(String)
    
#    def __repr__():
#        return f'{userid}_{movieid}_{tag}'

# %%
#class Links:
#    
#    __tablename__ = 'links'
#    movieid = Column(Integer)
#    imdbld = Column(Integer)
#    tmdbld = Column(String)
    
#    def __repr__():
#        return f'{movieid}_{imdbld}_{tmdbld}'

# %% [markdown]
# ### 2.3 Alternative to Classes: use the Autoload parameter with the Table object.

# %%
metadata = base.metadata

# %%
ratings = Table('ratings', metadata, autoload=True)
movies = Table('movies', metadata, autoload=True)
tags = Table('tags', metadata, autoload=True)
umr = Table('user_movie_ratings', metadata, autoload=True)
# Out:
# 2019-08-03 13:59:12,248 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2019-08-03 13:59:12,249 INFO sqlalchemy.engine.base.Engine {'table_name': 'ratings'}
# 2019-08-03 13:59:12,258 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2019-08-03 13:59:12,259 INFO sqlalchemy.engine.base.Engine {'table_oid': 24749}
# 2019-08-03 13:59:12,265 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2019-08-03 13:59:12,268 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:59:12,293 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2019-08-03 13:59:12,294 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:59:12,299 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2019-08-03 13:59:12,301 INFO sqlalchemy.engine.base.Engine {'table_oid': 24749}
# 2019-08-03 13:59:12,308 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2019-08-03 13:59:12,309 INFO sqlalchemy.engine.base.Engine {'table_oid': 24749}
# 2019-08-03 13:59:12,313 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2019-08-03 13:59:12,314 INFO sqlalchemy.engine.base.Engine {'table': 24749}
# 2019-08-03 13:59:12,322 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2019-08-03 13:59:12,327 INFO sqlalchemy.engine.base.Engine {'table_oid': 24749}
# 2019-08-03 13:59:12,347 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2019-08-03 13:59:12,349 INFO sqlalchemy.engine.base.Engine {'table_oid': 24749}
# 2019-08-03 13:59:12,355 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2019-08-03 13:59:12,356 INFO sqlalchemy.engine.base.Engine {'table_oid': 24749}
# 2019-08-03 13:59:12,360 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2019-08-03 13:59:12,361 INFO sqlalchemy.engine.base.Engine {'table_oid': 24749}
# 2019-08-03 13:59:12,368 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2019-08-03 13:59:12,369 INFO sqlalchemy.engine.base.Engine {'table_name': 'movies'}
# 2019-08-03 13:59:12,375 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2019-08-03 13:59:12,375 INFO sqlalchemy.engine.base.Engine {'table_oid': 24729}
# 2019-08-03 13:59:12,380 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
# 2019-08-03 13:59:12,382 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:59:12,390 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2019-08-03 13:59:12,391 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:59:12,401 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2019-08-03 13:59:12,402 INFO sqlalchemy.engine.base.Engine {'table_oid': 24729}
# 2019-08-03 13:59:12,405 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2019-08-03 13:59:12,406 INFO sqlalchemy.engine.base.Engine {'table_oid': 24729}
# 2019-08-03 13:59:12,409 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2019-08-03 13:59:12,410 INFO sqlalchemy.engine.base.Engine {'table': 24729}
# 2019-08-03 13:59:12,414 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2019-08-03 13:59:12,415 INFO sqlalchemy.engine.base.Engine {'table_oid': 24729}
# 2019-08-03 13:59:12,421 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2019-08-03 13:59:12,422 INFO sqlalchemy.engine.base.Engine {'table_oid': 24729}
# 2019-08-03 13:59:12,425 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2019-08-03 13:59:12,426 INFO sqlalchemy.engine.base.Engine {'table_oid': 24729}
# 2019-08-03 13:59:12,430 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2019-08-03 13:59:12,431 INFO sqlalchemy.engine.base.Engine {'table_oid': 24729}
# 2019-08-03 13:59:12,436 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2019-08-03 13:59:12,437 INFO sqlalchemy.engine.base.Engine {'table_name': 'tags'}
# 2019-08-03 13:59:12,439 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2019-08-03 13:59:12,441 INFO sqlalchemy.engine.base.Engine {'table_oid': 24740}
# 2019-08-03 13:59:12,445 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2019-08-03 13:59:12,445 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:59:12,449 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2019-08-03 13:59:12,450 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:59:12,454 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2019-08-03 13:59:12,455 INFO sqlalchemy.engine.base.Engine {'table_oid': 24740}
# 2019-08-03 13:59:12,458 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
# 2019-08-03 13:59:12,460 INFO sqlalchemy.engine.base.Engine {'table_oid': 24740}
# 2019-08-03 13:59:12,472 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2019-08-03 13:59:12,474 INFO sqlalchemy.engine.base.Engine {'table': 24740}
# 2019-08-03 13:59:12,489 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2019-08-03 13:59:12,491 INFO sqlalchemy.engine.base.Engine {'table_oid': 24740}
# 2019-08-03 13:59:12,497 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2019-08-03 13:59:12,498 INFO sqlalchemy.engine.base.Engine {'table_oid': 24740}
# 2019-08-03 13:59:12,500 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2019-08-03 13:59:12,501 INFO sqlalchemy.engine.base.Engine {'table_oid': 24740}
# 2019-08-03 13:59:12,503 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2019-08-03 13:59:12,504 INFO sqlalchemy.engine.base.Engine {'table_oid': 24740}
# 2019-08-03 13:59:12,508 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2019-08-03 13:59:12,509 INFO sqlalchemy.engine.base.Engine {'table_name': 'user_movie_ratings'}
# 2019-08-03 13:59:12,512 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2019-08-03 13:59:12,513 INFO sqlalchemy.engine.base.Engine {'table_oid': 24720}
# 2019-08-03 13:59:12,523 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2019-08-03 13:59:12,524 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:59:12,527 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2019-08-03 13:59:12,528 INFO sqlalchemy.engine.base.Engine {}
# 2019-08-03 13:59:12,606 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2019-08-03 13:59:12,608 INFO sqlalchemy.engine.base.Engine {'table_oid': 24720}
# 2019-08-03 13:59:12,616 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2019-08-03 13:59:12,617 INFO sqlalchemy.engine.base.Engine {'table_oid': 24720}
# 2019-08-03 13:59:12,622 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2019-08-03 13:59:12,623 INFO sqlalchemy.engine.base.Engine {'table': 24720}
# 2019-08-03 13:59:12,629 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
# 2019-08-03 13:59:12,630 INFO sqlalchemy.engine.base.Engine {'table_oid': 24720}
# 2019-08-03 13:59:12,647 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2019-08-03 13:59:12,648 INFO sqlalchemy.engine.base.Engine {'table_oid': 24720}
# 2019-08-03 13:59:12,666 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2019-08-03 13:59:12,668 INFO sqlalchemy.engine.base.Engine {'table_oid': 24720}
# 2019-08-03 13:59:12,672 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2019-08-03 13:59:12,673 INFO sqlalchemy.engine.base.Engine {'table_oid': 24720}

# %%
base.metadata.create_all(engine)

# %%
#base.metadata.reflect(engine)

# %%
base.metadata.tables.keys()

# %% [markdown]
# ### 2.4 Now perform all the RUD queries you want. For this the workflow is:
#
# * Create the queries
# * Add the queries to the session - nothing has changed on the db (its in a buffered state), so if you wipe the ram, you wipe what you've done
# * Commit the stuff to the session - data is in the db, the ram is cleared

# %%
# SELECT * FROM ratings LIMIT 10;
session.query(ratings).limit(10).all()

# %%
x = pd.DataFrame(session.query(ratings).filter(ratings.columns.movieId >5, ratings.columns.movieId <10).all())
x.head()

# %% [markdown]
# ## 3. Set up a NMF-model as a recommender with the following steps:
# * 1 - Reshape rating data into a user-movie matrix and fill NaN
# * 2 - Train NMF model (save it with pickle for reuse)
# * 3 - Take input from a "new user", convert it to a list/array which has length = len(list(movies.unique()))
# * 4 - Transform "vectorized" new user input with pre-trained NMF model
# * 5 - Take the resulting array and do the dot product of the original NMF cmponents

# %%
from sklearn.decomposition import NMF

# %%
umr_np = np.array(session.query(umr).all())

# %%
# Transpose it back to its original state to fit the model
umr_np = umr_np.T

# %%
len(umr_np.T)

# %%
#create a model and set the hyperparameters
# model assumes R ~ PQ'

nmf = NMF(n_components=5, init='random', random_state=10)

# %%
nmf.fit(umr_np)

# %%
# movie-genre matrix
Q = nmf.components_

# %%
# user-genre matrix
P = nmf.transform(umr_np)

# %%
R_pred = np.dot(P,Q)

# %% [markdown]
# #### This is the loss between R and R-hat

# %%
print(model.reconstruction_err_) #reconstruction error

# %%
# recreate the loss function using numpy
diff = R_df.values - R_hat_df.values
diff_sq = diff**2
reconst_error = math.sqrt(diff_sq.sum())
